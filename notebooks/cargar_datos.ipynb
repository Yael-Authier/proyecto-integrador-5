# %% [markdown]
# # Carga de datos
#
# ## Objetivo
# En este notebook se realiza la carga inicial de la base de datos que será utilizada durante el proyecto de predicción de riesgo crediticio.
#
# ## Actividades
# - Importación de librerías necesarias.
# - Lectura del archivo Excel.
# - Validación inicial de la estructura del dataset.
# - Visualización preliminar de los datos.

# %%
import pandas as pd
import numpy as np

ruta_base = "../data/Base_de_datos.xlsx"

df = pd.read_excel(ruta_base)

df.head()

# %% [markdown]
# ## Exploración inicial de la estructura de datos
#
# En esta sección se realiza una revisión general del dataset para comprender:
# - Cantidad de registros y variables.
# - Tipos de datos.
# - Presencia de valores nulos.
# - Estructura general de la información.

# %%
print("Dimensiones del dataset:")
print(df.shape)

print("\nNombres de columnas:")
print(df.columns)

print("\nInformación general:")
df.info()
# Out:
# Dimensiones del dataset:
# (10763, 23)
#
# Nombres de columnas:
# Index(['tipo_credito', 'fecha_prestamo', 'capital_prestado', 'plazo_meses',
#        'edad_cliente', 'tipo_laboral', 'salario_cliente',
#        'total_otros_prestamos', 'cuota_pactada', 'puntaje',
#        'puntaje_datacredito', 'cant_creditosvigentes', 'huella_consulta',
#        'saldo_mora', 'saldo_total', 'saldo_principal', 'saldo_mora_codeudor',
#        'creditos_sectorFinanciero', 'creditos_sectorCooperativo',
#        'creditos_sectorReal', 'promedio_ingresos_datacredito',
#        'tendencia_ingresos', 'Pago_atiempo'],
#       dtype='object')
#
# Información general:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10763 entries, 0 to 10762
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tipo_credito                   10763 non-null  int64
# ...
